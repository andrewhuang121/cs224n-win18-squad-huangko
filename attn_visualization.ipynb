# %%
import pickle
import gzip
import numpy as np

import xtermcolor as c

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Import

# %%
with open('./code/attn_activation.pkl', 'rb') as f:
    u = pickle._Unpickler(f)
    u.encoding = 'latin1'
    attn_activation = u.load()

with open('./code/batch.pkl', 'rb') as f:
    u = pickle._Unpickler(f)
    u.encoding = 'latin1'
    batch = u.load()

with open('./code/word2id.pkl', 'rb') as f:
    u = pickle._Unpickler(f)
    u.encoding = 'latin1'
    word2id = u.load()

# %%
def softmax(x, dim):
    return np.exp(x) / np.expand_dims(np.sum(np.exp(x), axis=dim), dim)

def top(x, num):
    arr = x.argsort()[-num:][::-1]
    x[arr] = 1
    x[x != 1] = 0
    return x

def masked_softmax(logits, mask, dim):
    exp_mask = (1 - mask.astype('float')) * (-1e30) # -large where there's padding, 0 elsewhere
    masked_logits = logits + np.expand_dims(exp_mask, 1) # where there's padding, set logits to -large
    prob_dist = softmax(masked_logits, dim)
    return prob_dist

# %% [markdown]
# ## Visualize

# %%
print(c.colorize("Hello World", rgb=3) + c.colorize("Hello World", rgb=225))
# Out:
# Hello WorldHello World

# %%
" ".join(batch['context_tokens'][0])
# Out:
# 'in the early 13th century , the khwarazmian dynasty was governed by shah ala ad-din muhammad . genghis khan saw the potential advantage in khwarezmia as a commercial trading partner using the silk road , and he initially sent a 500-man caravan to establish official trade ties with the empire . however , inalchuq , the governor of the khwarezmian city of otrar , attacked the caravan that came from mongolia , claiming that the caravan contained spies and therefore was a conspiracy against khwarezmia . the situation became further complicated because the governor later refused to make repayments for the looting of the caravans and handing over the perpetrators . genghis khan then sent again a second group of three ambassadors ( two mongols and a muslim ) to meet the shah himself instead of the governor inalchuq . the shah had all the men shaved and the muslim beheaded and sent his head back with the two remaining ambassadors . this was seen as an affront and insult to genghis khan . outraged , genghis khan planned one of his largest invasion campaigns by organizing together around 100,000 soldiers ( 10 tumens ) , his most capable generals and some of his sons . he left a commander and number of troops in china , designated his successors to be his family members and likely appointed Ã¶gedei to be his immediate successor and then went out to khwarezmia .'

# %%
" ".join(batch['qn_tokens'][0])
# Out:
# 'what trading route joined khwarezmia and the mongol empire ?'

# %%
idx = -2

for i, word in enumerate(batch['qn_tokens'][idx]):
    print("Activation for the word:      %s" % word)
    context_activation = masked_softmax(attn_activation[idx], batch['context_mask'][idx], 0)[:,i]
    context_activation = top(context_activation, 5)
    output = " ".join([c.colorize(w, rgb=int(255 * context_activation[j])) for j, w in enumerate(batch['context_tokens'][idx])])
    print(output)
    print("")
# Out:
# Activation for the word:      what
# super bowl 50 was an american football game to determine the champion of the national football league ( nfl ) for the 2015 season . the american football conference ( afc ) champion denver broncos defeated the national football conference ( nfc ) champion carolina panthers 24â10 to earn their third super bowl title . the game was played on february 7 , 2016 , at levi 's stadium in the san francisco bay area at santa clara , california . as this was the 50th super bowl , the league emphasized the " golden anniversary " with various gold-themed initiatives , as well as temporarily suspending the tradition of naming each super bowl game with roman numerals ( under which the game would have been known as " super bowl l " ) , so that the logo could prominently feature the arabic numerals 50 .
#
# Activation for the word:      city
# super bowl 50 was an american football game to determine the champion of the national football league ( nfl ) for the 2015 season . the american football conference ( afc ) champion denver broncos defeated the national football conference ( nfc ) champion carolina panthers 24â10 to earn their third super bowl title . the game was played on february 7 , 2016 , at levi 's stadium in the san francisco bay area at santa clara , california . as this was the 50th super bowl , the league emphasized the " golden anniversary " with various gold-themed initiatives , as well as temporarily suspending the tradition of naming each super bowl game with roman numerals ( under which the game would have been known as " super bowl l " ) , so that the logo could prominently feature the arabic numerals 50 .
#
# Activation for the word:      did
# super bowl 50 was an american football game to determine the champion of the national football league ( nfl ) for the 2015 season . the american football conference ( afc ) champion denver broncos defeated the national football conference ( nfc ) champion carolina panthers 24â10 to earn their third super bowl title . the game was played on february 7 , 2016 , at levi 's stadium in the san francisco bay area at santa clara , california . as this was the 50th super bowl , the league emphasized the " golden anniversary " with various gold-themed initiatives , as well as temporarily suspending the tradition of naming each super bowl game with roman numerals ( under which the game would have been known as " super bowl l " ) , so that the logo could prominently feature the arabic numerals 50 .
#
# Activation for the word:      super
# super bowl 50 was an american football game to determine the champion of the national football league ( nfl ) for the 2015 season . the american football conference ( afc ) champion denver broncos defeated the national football conference ( nfc ) champion carolina panthers 24â10 to earn their third super bowl title . the game was played on february 7 , 2016 , at levi 's stadium in the san francisco bay area at santa clara , california . as this was the 50th super bowl , the league emphasized the " golden anniversary " with various gold-themed initiatives , as well as temporarily suspending the tradition of naming each super bowl game with roman numerals ( under which the game would have been known as " super bowl l " ) , so that the logo could prominently feature the arabic numerals 50 .
#
# Activation for the word:      bowl
# super bowl 50 was an american football game to determine the champion of the national football league ( nfl ) for the 2015 season . the american football conference ( afc ) champion denver broncos defeated the national football conference ( nfc ) champion carolina panthers 24â10 to earn their third super bowl title . the game was played on february 7 , 2016 , at levi 's stadium in the san francisco bay area at santa clara , california . as this was the 50th super bowl , the league emphasized the " golden anniversary " with various gold-themed initiatives , as well as temporarily suspending the tradition of naming each super bowl game with roman numerals ( under which the game would have been known as " super bowl l " ) , so that the logo could prominently feature the arabic numerals 50 .
#
# Activation for the word:      50
# super bowl 50 was an american football game to determine the champion of the national football league ( nfl ) for the 2015 season . the american football conference ( afc ) champion denver broncos defeated the national football conference ( nfc ) champion carolina panthers 24â10 to earn their third super bowl title . the game was played on february 7 , 2016 , at levi 's stadium in the san francisco bay area at santa clara , california . as this was the 50th super bowl , the league emphasized the " golden anniversary " with various gold-themed initiatives , as well as temporarily suspending the tradition of naming each super bowl game with roman numerals ( under which the game would have been known as " super bowl l " ) , so that the logo could prominently feature the arabic numerals 50 .
#
# Activation for the word:      take
# super bowl 50 was an american football game to determine the champion of the national football league ( nfl ) for the 2015 season . the american football conference ( afc ) champion denver broncos defeated the national football conference ( nfc ) champion carolina panthers 24â10 to earn their third super bowl title . the game was played on february 7 , 2016 , at levi 's stadium in the san francisco bay area at santa clara , california . as this was the 50th super bowl , the league emphasized the " golden anniversary " with various gold-themed initiatives , as well as temporarily suspending the tradition of naming each super bowl game with roman numerals ( under which the game would have been known as " super bowl l " ) , so that the logo could prominently feature the arabic numerals 50 .
#
# Activation for the word:      place
# super bowl 50 was an american football game to determine the champion of the national football league ( nfl ) for the 2015 season . the american football conference ( afc ) champion denver broncos defeated the national football conference ( nfc ) champion carolina panthers 24â10 to earn their third super bowl title . the game was played on february 7 , 2016 , at levi 's stadium in the san francisco bay area at santa clara , california . as this was the 50th super bowl , the league emphasized the " golden anniversary " with various gold-themed initiatives , as well as temporarily suspending the tradition of naming each super bowl game with roman numerals ( under which the game would have been known as " super bowl l " ) , so that the logo could prominently feature the arabic numerals 50 .
#
# Activation for the word:      in
# super bowl 50 was an american football game to determine the champion of the national football league ( nfl ) for the 2015 season . the american football conference ( afc ) champion denver broncos defeated the national football conference ( nfc ) champion carolina panthers 24â10 to earn their third super bowl title . the game was played on february 7 , 2016 , at levi 's stadium in the san francisco bay area at santa clara , california . as this was the 50th super bowl , the league emphasized the " golden anniversary " with various gold-themed initiatives , as well as temporarily suspending the tradition of naming each super bowl game with roman numerals ( under which the game would have been known as " super bowl l " ) , so that the logo could prominently feature the arabic numerals 50 .
#
# Activation for the word:      ?
# super bowl 50 was an american football game to determine the champion of the national football league ( nfl ) for the 2015 season . the american football conference ( afc ) champion denver broncos defeated the national football conference ( nfc ) champion carolina panthers 24â10 to earn their third super bowl title . the game was played on february 7 , 2016 , at levi 's stadium in the san francisco bay area at santa clara , california . as this was the 50th super bowl , the league emphasized the " golden anniversary " with various gold-themed initiatives , as well as temporarily suspending the tradition of naming each super bowl game with roman numerals ( under which the game would have been known as " super bowl l " ) , so that the logo could prominently feature the arabic numerals 50 .

# %%
batch['qn_tokens']
# Out:
# (['who',
#   'designed',
#   'the',
#   'new',
#   'medieval',
#   'and',
#   'renaissance',
#   'galleries',
#   'which',
#   'opened',
#   'in',
#   '2009',
#   '?'],
#  ['what',
#   'company',
#   'had',
#   'a',
#   'contest',
#   'to',
#   'win',
#   'a',
#   'free',
#   'super',
#   'bowl',
#   'commercial',
#   '?'],
#  ['the',
#   'freedom',
#   'to',
#   'provide',
#   'services',
#   'under',
#   'tfeu',
#   'article',
#   '56',
#   'applies',
#   'to',
#   'who',
#   '?'],
#  ['when',
#   'did',
#   'the',
#   'germanic',
#   'tribes',
#   'claim',
#   'territory',
#   'in',
#   'north',
#   'and',
#   'west',
#   'europe',
#   '?'],
#  ['what',
#   'type',
#   'of',
#   'immune',
#   'cells',
#   'help',
#   'to',
#   'destroy',
#   'abnormal',
#   'cells',
#   'in',
#   'tumors',
#   '?'],
#  ['what',
#   'typically',
#   'involves',
#   'mass',
#   'production',
#   'of',
#   'similar',
#   'items',
#   'without',
#   'a',
#   'designated',
#   'purchaser',
#   '?'],
#  ['what',
#   'is',
#   'considered',
#   'the',
#   'centerpiece',
#   'of',
#   'the',
#   'jameel',
#   'gallery',
#   'of',
#   'islamic',
#   'art',
#   '?'],
#  ['which',
#   'building',
#   'was',
#   'the',
#   'nfl',
#   'experience',
#   'held',
#   'at',
#   'for',
#   'super',
#   'bowl',
#   '50',
#   '?'],
#  ['what',
#   'are',
#   'examples',
#   'of',
#   'differentiated',
#   'effector',
#   'cells',
#   'that',
#   'peak',
#   'during',
#   'wake',
#   'periods',
#   '?'],
#  ['what',
#   'complexity',
#   'class',
#   'is',
#   'commonly',
#   'characterized',
#   'by',
#   'unknown',
#   'algorithms',
#   'to',
#   'enhance',
#   'solvability',
#   '?'],
#  ['the',
#   'spin',
#   'of',
#   'what',
#   'can',
#   'produce',
#   'a',
#   'magnetic',
#   'effect',
#   'to',
#   'oxygen',
#   'molecules',
#   '?'],
#  ['what',
#   'type',
#   'of',
#   'forested',
#   'areas',
#   'can',
#   'be',
#   'found',
#   'on',
#   'the',
#   'highest',
#   'terrace',
#   '?'],
#  ['what',
#   'do',
#   'rules',
#   'about',
#   'conflict',
#   'of',
#   'interest',
#   'involving',
#   'doctors',
#   'diagnosing',
#   'patients',
#   'resemble',
#   '?'],
#  ['in',
#   'what',
#   'types',
#   'of',
#   'organisms',
#   'did',
#   'the',
#   'adaptive',
#   'immune',
#   'system',
#   'first',
#   'evolve',
#   '?'],
#  ['what',
#   'reality',
#   'series',
#   'was',
#   'the',
#   'first',
#   'spinoff',
#   'of',
#   'the',
#   'bachelor',
#   'for',
#   'abc',
#   '?'],
#  ['what',
#   'does',
#   'the',
#   'capabilities',
#   'approach',
#   'look',
#   'at',
#   'poverty',
#   'as',
#   'a',
#   'form',
#   'of',
#   '?'],
#  ['in',
#   'nepalese',
#   'private',
#   'schools',
#   ',',
#   'what',
#   'is',
#   'the',
#   'primary',
#   'language',
#   'of',
#   'instruction',
#   '?'],
#  ['the',
#   'art',
#   'noveau',
#   'style',
#   'of',
#   'glassware',
#   'is',
#   'represented',
#   'by',
#   'which',
#   'two',
#   'artists',
#   '?'],
#  ['when',
#   'would',
#   'a',
#   'person',
#   'be',
#   'considered',
#   'to',
#   'be',
#   'excising',
#   'a',
#   'constitutional',
#   'impasse',
#   '?'],
#  ['what',
#   'museum',
#   'specializes',
#   'in',
#   'cultural',
#   'history',
#   'and',
#   'civilizations',
#   'of',
#   'the',
#   'western',
#   'hemisphere',
#   '?'],
#  ['what',
#   'analyst',
#   'did',
#   'not',
#   'agree',
#   'with',
#   'the',
#   'ruling',
#   'of',
#   'the',
#   'incomplete',
#   'pass',
#   '?'],
#  ['how',
#   'many',
#   'species',
#   'of',
#   'trees',
#   'can',
#   'be',
#   'found',
#   'in',
#   'the',
#   'amazon',
#   'rainforest',
#   '?'],
#  ['what',
#   'remained',
#   'an',
#   'important',
#   'issue',
#   'in',
#   'scottish',
#   'national',
#   'identity',
#   'for',
#   'many',
#   'years',
#   '?'],
#  ['besides',
#   'public',
#   'key',
#   'cryptography',
#   ',',
#   'what',
#   'is',
#   'another',
#   'application',
#   'for',
#   'prime',
#   'numbers',
#   '?'],
#  ['what',
#   'series',
#   'was',
#   'created',
#   'by',
#   'former',
#   'doctor',
#   'who',
#   'producer',
#   'russell',
#   't.',
#   'davies',
#   '?'],
#  ['what',
#   'network',
#   'assumed',
#   'the',
#   'rights',
#   'to',
#   'the',
#   'miss',
#   'america',
#   'pageant',
#   'in',
#   '2006',
#   '?'],
#  ['what',
#   'does',
#   'it',
#   'take',
#   'a',
#   'country',
#   'with',
#   'high',
#   'inequality',
#   'longer',
#   'to',
#   'achieve',
#   '?'],
#  ['what',
#   'trend',
#   'increases',
#   'the',
#   'organic',
#   'composition',
#   'of',
#   'capital',
#   'over',
#   'the',
#   'long',
#   'term',
#   '?'],
#  ['who',
#   'was',
#   'delegated',
#   'command',
#   'of',
#   'the',
#   'mongol',
#   'forces',
#   'against',
#   'the',
#   'jin',
#   'dynasty',
#   '?'],
#  ['what',
#   'percentage',
#   'of',
#   'electricity',
#   'was',
#   'made',
#   'by',
#   'steam',
#   'turbine',
#   'in',
#   'the',
#   '1990s',
#   '?'],
#  ['a',
#   'replica',
#   'of',
#   'what',
#   'landmark',
#   'was',
#   'present',
#   'at',
#   'super',
#   'bowl',
#   'opening',
#   'night',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'axis',
#   'of',
#   'warsaw',
#   'which',
#   'divides',
#   'it',
#   'into',
#   'two',
#   'parts',
#   '?'],
#  ['what',
#   'other',
#   'aspect',
#   'of',
#   'luther',
#   "'s",
#   'life',
#   'was',
#   'affected',
#   'by',
#   'his',
#   'health',
#   '?'],
#  ['developments',
#   'in',
#   'which',
#   'scientists',
#   'influenced',
#   'the',
#   'creation',
#   'of',
#   'pharmacology',
#   'in',
#   'medieval',
#   'islam',
#   '?'],
#  ['what',
#   'dynasty',
#   'did',
#   'genghis',
#   'khan',
#   'plan',
#   'to',
#   'attack',
#   'after',
#   'conquering',
#   'western',
#   'xia',
#   '?'],
#  ['which',
#   'of',
#   'temÃ¼jin',
#   "'s",
#   'childhood',
#   'friends',
#   'did',
#   'toghrul',
#   'suggest',
#   'he',
#   'also',
#   'enlist',
#   '?'],
#  ['besides',
#   'britain',
#   'and',
#   'north',
#   'america',
#   ',',
#   'where',
#   'else',
#   'did',
#   'huguenot',
#   'refugees',
#   'settle',
#   '?'],
#  ['what',
#   'building',
#   'material',
#   'does',
#   'the',
#   'entrance',
#   'hall',
#   'and',
#   'flanking',
#   'staircases',
#   'use',
#   'predominantly',
#   '?'],
#  ['which',
#   'park',
#   'hosts',
#   'the',
#   'largest',
#   'civil',
#   'war',
#   'reenactment',
#   'on',
#   'the',
#   'west',
#   'coast',
#   '?'],
#  ['at',
#   'what',
#   'size',
#   'and',
#   'larger',
#   'can',
#   'drugs',
#   'elicit',
#   'a',
#   'neutralizing',
#   'immune',
#   'response',
#   '?'],
#  ['what',
#   'ended',
#   'the',
#   'need',
#   'for',
#   'abc',
#   'to',
#   'maintain',
#   'interests',
#   'in',
#   'other',
#   'countries',
#   '?'],
#  ['in',
#   '2012-13',
#   ',',
#   'abc',
#   'debuted',
#   'a',
#   'comedy',
#   'last',
#   'man',
#   'standing',
#   'starring',
#   'who',
#   '?'],
#  ['in',
#   'what',
#   'episode',
#   'did',
#   'doctor',
#   'who',
#   'get',
#   'a',
#   'new',
#   'cycle',
#   'of',
#   'regenerations',
#   '?'],
#  ['how',
#   'old',
#   'was',
#   'chopin',
#   'when',
#   'he',
#   'moved',
#   'to',
#   'warsaw',
#   'with',
#   'his',
#   'family',
#   '?'],
#  ['what',
#   'president',
#   'of',
#   'the',
#   'university',
#   'transformed',
#   'it',
#   'into',
#   'a',
#   'modern',
#   'research',
#   'university',
#   '?'],
#  ['most',
#   'aspects',
#   'of',
#   'transport',
#   'safety',
#   'is',
#   'a',
#   'subject',
#   'dealt',
#   'with',
#   'by',
#   'whom',
#   '?'],
#  ['most',
#   'antibiotics',
#   'target',
#   'bacteria',
#   'and',
#   'do',
#   "n't",
#   'affect',
#   'what',
#   'class',
#   'of',
#   'organisms',
#   '?'],
#  ['what',
#   'was',
#   'the',
#   'teacher',
#   "'s",
#   'role',
#   'while',
#   'the',
#   'child',
#   'was',
#   'with',
#   'them',
#   '?'],
#  ['besides',
#   'abc',
#   'news',
#   ',',
#   'what',
#   'other',
#   'division',
#   'was',
#   'roone',
#   'arledge',
#   'president',
#   'of',
#   '?'],
#  ['who',
#   'recovered',
#   'the',
#   'fumble',
#   'and',
#   'ran',
#   'the',
#   'ball',
#   'in',
#   'for',
#   'a',
#   'touchdown',
#   '?'],
#  ['who',
#   'directed',
#   'luther',
#   'away',
#   'from',
#   'self-reflection',
#   'and',
#   'towards',
#   'the',
#   'merits',
#   'of',
#   'christ',
#   '?'],
#  ['what',
#   'satellite',
#   'enabled',
#   'sky',
#   'digital',
#   'to',
#   'launch',
#   'an',
#   'all',
#   'new',
#   'digital',
#   'service',
#   '?'],
#  ['what',
#   'hymn',
#   'did',
#   'luther',
#   'write',
#   'after',
#   'the',
#   'martyrdom',
#   'of',
#   'esch',
#   'and',
#   'voes',
#   '?'],
#  ['the',
#   'teacher',
#   "'s",
#   'in',
#   'a',
#   'platoon',
#   'style',
#   'teaching',
#   'are',
#   'usually',
#   'more',
#   '_____',
#   '?'],
#  ['what',
#   'chemical',
#   'element',
#   'was',
#   'the',
#   'cause',
#   'of',
#   'the',
#   'apollo',
#   '1',
#   'disastrous',
#   'outcome',
#   '?'],
#  ['what',
#   'governing',
#   'body',
#   'appoints',
#   'commissioners',
#   'and',
#   'the',
#   'board',
#   'of',
#   'european',
#   'central',
#   'bank',
#   '?'],
#  ['what',
#   'theatre',
#   'was',
#   'the',
#   'best',
#   'example',
#   'of',
#   '"',
#   'polish',
#   'monumental',
#   'theatre',
#   '"',
#   '?'],
#  ['what',
#   'type',
#   'of',
#   'combustion',
#   'does',
#   'the',
#   'slow',
#   'reaction',
#   'of',
#   'triplet',
#   'oxygen',
#   'prevent',
#   '?'],
#  ['antibodies',
#   'are',
#   'transferred',
#   'to',
#   'the',
#   'gut',
#   'of',
#   'the',
#   'infant',
#   'through',
#   'what',
#   'means',
#   '?'],
#  ['what',
#   'is',
#   'something',
#   'that',
#   'teacher',
#   "'s",
#   'are',
#   'at',
#   'a',
#   'high',
#   'risk',
#   'for',
#   '?'])
